# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Reading

# %%
books = pd.read_csv('Books.csv')
books
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_22048\2199899805.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv')
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %%
users = pd.read_csv('Users.csv')
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
ratings = pd.read_csv('Ratings.csv')
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %% [markdown]
# # Data Cleaning

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %% [markdown]
# ## Merge ratings and books on 'ISBN'

# %%
ratings_with_name = ratings.merge(books,on='ISBN')
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] >200

digik_users = x[x].index
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(digik_users)]

y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

df = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

df.fillna(0,inplace=True)


df
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %% [markdown]
# ## Recommendation System

# %%
# Get input from user for book title
user_input = input("Enter a book title to get recommendations: ")

# Filter ratings for the entered book title
filtered_ratings = ratings_with_name[ratings_with_name['Book-Title'].str.contains(user_input, case=False)]
# Calculate average rating for each book
book_ratings_avg = filtered_ratings.groupby('Book-Title')['Book-Rating'].mean().reset_index()

# Sort books by average rating in descending order
recommended_books = book_ratings_avg.sort_values(by='Book-Rating', ascending=False)

# Print recommended books
print(f"Recommended books related to '{user_input}':")
for index, row in recommended_books.iterrows():
    print(f"{row['Book-Title']}: Average Rating {row['Book-Rating']:.2f}")
# Out:
# Enter a book title to get recommendations: The Boys
# Recommended books related to 'The Boys':
# Dead End Kids: Gang Girls and the Boys They Know: Average Rating 10.00
# Bach, Beethoven, and the Boys: Music History As It Ought to Be Taught: Average Rating 10.00
# Who Am I Without Him? : Short Stories About Girls and the Boys in Their Lives: Average Rating 9.00
# Accidental Empires: How the Boys of Silicon Valley Make Their Millions, Battle Foreign Competition, and Still Can't Get a Date: Average Rating 8.50
# Ed McBain's Give the Boys a Great Big Hand: Average Rating 7.50
# The real thing: A guide to separating the genuine from the ersatz, the man from the boys, and the wheat from the chaff: Average Rating 7.00
# The Boys and Their Baby (Stonewall Inn Editions): Average Rating 7.00
# Across America with the Boys: Average Rating 7.00
# Me and the Boys: The Glorious Adventures of Gini Kincaid : My Perilous Times in the Territory : A Novel: Average Rating 4.50
# ...
